# %% [markdown]
# ### Première vue :

# %%
import pandas as pd

# Récupération du dataset
path = "https://static.openfoodfacts.org/data/en.openfoodfacts.org.products.csv.gz"
df = pd.read_csv(path, nrows=10000, sep='\t',  encoding="utf-8", low_memory = False, na_filter = True )     
df
# Out:
#             code                                                url  \
# 0             54  http://world-en.openfoodfacts.org/product/0000...
# 1             63  http://world-en.openfoodfacts.org/product/0000...
# 2            114  http://world-en.openfoodfacts.org/product/0000...
# 3              1  http://world-en.openfoodfacts.org/product/0000...
# 4            105  http://world-en.openfoodfacts.org/product/0000...
# ...          ...                                                ...
# 9995       15899  http://world-en.openfoodfacts.org/product/0001...
# 9996  1590000211  http://world-en.openfoodfacts.org/product/0001...
# 9997  1590006450  http://world-en.openfoodfacts.org/product/0001...
# 9998  1590006978  http://world-en.openfoodfacts.org/product/0001...
# 9999  1590013401  http://world-en.openfoodfacts.org/product/0001...
#
#               creator   created_t      created_datetime  last_modified_t  \
# 0             kiliweb  1582569031  2020-02-24T18:30:31Z       1733085204
# ...

# %%
df_to_clean = df 
df_to_clean.info() 
df_to_clean.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Columns: 199 entries, last_modified_by to acidity_100g
# dtypes: float64(131), int64(1), object(67)
# memory usage: 15.2+ MB
#        last_updated_t  cities  allergens_en  serving_quantity  additives_n  \
# count    1.000000e+04     0.0           0.0       3062.000000  1704.000000
# mean     1.734791e+09     NaN           NaN        124.460211     1.860329
# std      7.520425e+06     NaN           NaN        529.820139     2.778235
# min      1.707490e+09     NaN           NaN          0.000000     0.000000
# 25%      1.728057e+09     NaN           NaN         25.000000     0.000000
# 50%      1.738819e+09     NaN           NaN         50.500000     1.000000
# 75%      1.740183e+09     NaN           NaN        130.000000     3.000000
# max      1.740968e+09     NaN           NaN      28000.000000    19.000000
#
#        additives  nutriscore_score   nova_group  environmental_score_score  \
# ...

# %%
# Sélection des colonnes numériques
num_cols =df_to_clean.select_dtypes(include=['int64', 'float64']).columns.tolist()
print(f"Colonnes numériques détectées : {num_cols}")
# Out:
# Colonnes numériques détectées : ['last_updated_t', 'cities', 'allergens_en', 'serving_quantity', 'additives_n', 'additives', 'nutriscore_score', 'nova_group', 'environmental_score_score', 'product_quantity', 'unique_scans_n', 'completeness', 'last_image_t', 'energy-kj_100g', 'energy-kcal_100g', 'energy_100g', 'energy-from-fat_100g', 'fat_100g', 'saturated-fat_100g', 'butyric-acid_100g', 'caproic-acid_100g', 'caprylic-acid_100g', 'capric-acid_100g', 'lauric-acid_100g', 'myristic-acid_100g', 'palmitic-acid_100g', 'stearic-acid_100g', 'arachidic-acid_100g', 'behenic-acid_100g', 'lignoceric-acid_100g', 'cerotic-acid_100g', 'montanic-acid_100g', 'melissic-acid_100g', 'unsaturated-fat_100g', 'monounsaturated-fat_100g', 'omega-9-fat_100g', 'polyunsaturated-fat_100g', 'omega-3-fat_100g', 'omega-6-fat_100g', 'alpha-linolenic-acid_100g', 'eicosapentaenoic-acid_100g', 'docosahexaenoic-acid_100g', 'linoleic-acid_100g', 'arachidonic-acid_100g', 'gamma-linolenic-acid_100g', 'dihomo-gamma-linolenic
# ...

# %%
#Ne pas suup les colonnes en dure mais en optionnel 
# Calcul du pourcentage de valeurs manquantes par colonne
missing_percentage =df_to_clean.isnull().mean() * 100  
print(missing_percentage)
# Out:
# last_modified_by              3.47
# last_updated_t                0.00
# last_updated_datetime         0.00
# product_name                 13.25
# abbreviated_product_name     99.94
#                              ...
# inositol_100g               100.00
# carnitine_100g              100.00
# sulphate_100g               100.00
# nitrate_100g                100.00
# acidity_100g                100.00
# Length: 199, dtype: float64

# %%
#Supprimer les colonnes qui ne servent pas à notre étude 
columns_drop = ['code', 'url', 'creator', 'created_t', 'created_datetime', 'last_modified_t', 'last_modified_datetime' ]

# Suppression des colonnes
df_cleaned =df_to_clean.drop(columns=columns_drop)

# Affichage du DataFrame après suppression
print(df_cleaned)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[96], line 5
#       2 columns_drop = ['code', 'url', 'creator', 'created_t', 'created_datetime', 'last_modified_t', 'last_modified_datetime' ]
#       4 # Suppression des colonnes
# ----> 5 df_cleaned =df_to_clean.drop(columns=columns_drop)
#       7 # Affichage du DataFrame après suppression
#       8 print(df_cleaned)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# ...

# %%
 # Calcul du pourcentage de valeurs manquantes pour chaque colonne
missing_percentage = df_to_clean.isnull().mean() * 100

# Sélection des colonnes à garder : celles avec moins de 80% de valeurs manquantes
df_cleaned = df.loc[:, missing_percentage <= 90]

# Affichage du DataFrame après suppression
print(df_cleaned)


threshold = 70
columns_to_drop = percent_missing[
    percent_missing.values > threshold].index
columns_to_drop
# Out:
#      last_modified_by  last_updated_t last_updated_datetime  \
# 0                 NaN      1740205422  2025-02-22T06:23:42Z
# 1       waistline-app      1740360377  2025-02-24T01:26:17Z
# 2        smoothie-app      1740075018  2025-02-20T18:10:18Z
# 3        smoothie-app      1740924602  2025-03-02T14:10:02Z
# 4                 NaN      1740085032  2025-02-20T20:57:12Z
# ...               ...             ...                   ...
# 9995      macrofactor      1740049730  2025-02-20T11:08:50Z
# 9996   omnomnotes-app      1707874424  2024-02-14T01:33:44Z
# 9997     fix-code-bot      1728036862  2024-10-04T10:14:22Z
# 9998     fix-code-bot      1738847008  2025-02-06T13:03:28Z
# 9999     fix-code-bot      1738847008  2025-02-06T13:03:28Z
#
#                                   product_name quantity          brands  \
# 0                Limonade artisanale a la rose      NaN             NaN
# 1     Mozzarella Schnittfest Gerieben 45% Fett      NaN   Gut & Gunstig
# ...
