# %%
# Imports nécessaires
import pandas as pd
from scripts.smart_sampling import smart_sample

# Chargement du dataset avec les paramètres adaptés
df = pd.read_csv(
    '../data/en.openfoodfacts.org.products.csv',
    nrows=10000,
    sep='\t',
    low_memory=False,
    encoding='utf-8'
)
# Création automatique de l'échantillon
sample, metrics = smart_sample(df)
# Out:
# Colonnes sélectionnées pour la stratification:
# - nutriscore_grade: 7 catégories, score=0.347
# - pnns_groups_1: 11 catégories, score=0.343
# - environmental_score_grade: 9 catégories, score=0.318
#
# Colonnes numériques sélectionnées:
# - energy_100g: score=0.868, std=2092.562, missing=44.0%
# - energy-kcal_100g: score=0.867, std=511.821, missing=44.4%
# - carbohydrates_100g: score=0.864, std=42.411, missing=45.3%
# - proteins_100g: score=0.861, std=46.768, missing=46.2%
# - fat_100g: score=0.860, std=20.903, missing=46.5%
